# %%
import numpy as np
import pandas as pd
np.random.seed(1)
Random_df = pd.DataFrame({"C":np.random.normal(35,100,size=10),"D":np.random.normal(4,10,size=10)})

Random_df
# Out:
#             C          D
# 0  197.434536  18.621079
# 1  -26.175641 -16.601407
# 2  -17.817175   0.775828
# 3  -72.296862   0.159456
# 4  121.540763  15.337694
# 5 -195.153870  -6.998913
# 6  209.481176   2.275718
# 7  -41.120690  -4.778584
# 8   66.903910   4.422137
# 9   10.062962   9.828152

# %%
import matplotlib.pyplot as plt
#Random_df = Random_df.sort_values(by="C")
plt.plot(Random_df["D"],Random_df["C"])

# %%
nornd = (np.random.normal(0,10,size=10))

#nornd = nornd.sort()

plt.plot(nornd)
