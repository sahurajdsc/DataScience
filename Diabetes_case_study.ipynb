# %%
from sklearn.datasets import load_diabetes

data = load_diabetes()

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X=data.data
y=data.target

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

LR = LinearRegression()

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

print(X_train.shape)
print(X_test.shape)

LR.fit(X_train,y_train)
# Out:
# (353, 10)
# (89, 10)
# LinearRegression()

# %%
y_test_pred = LR.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error

r2 = r2_score(y_test,y_test_pred)
rmse = np.sqrt(mean_squared_error(y_test,y_test_pred))
print(r2)
print(rmse)
# Out:
# 0.5188118914964637
# 48.72710829141399

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

print(X_train_poly.shape)
print(X_test_poly.shape)
# Out:
# (353, 66)
# (89, 66)

# %%
LR_poly = LinearRegression()
LR_poly.fit(X_train_poly,y_train)
y_test_pred_poly = LR_poly.predict(X_test_poly)

R2_poly = r2_score(y_test,y_test_pred_poly)

print(R2_poly)
# Out:
# 0.5188118914964637

# %%
import seaborn as sns
import matplotlib.pyplot as plt
        
fig_title = ['age','sex','bmi','bp','LDL','HDL','tch','ltg','blood_sugar']

for i in range(0,10):
    plt.scatter(data.target,data.data[:,i])
    #plt.subplot(1,2,i+1)
    plt.ylabel("Disease_progression")
    plt.xlabel(str(fig_title[i]))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [94], in <cell line: 6>()
#       8 #plt.subplot(1,2,i+1)
#       9 plt.ylabel("Disease_progression")
# ---> 10 plt.xlabel(str(fig_title[i]))
#      11 plt.show()
#
# IndexError: list index out of range
