# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\RajnarayanSahu\OneDrive - National Pen Company\Documents\All imp files\Data Science\Python-20220910T133417Z-001\Python\Solved_by_own\K_means\WineQuality\winequality.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for columns in df.columns:
    if df[columns].dtypes == "object":
        df[columns] = le.fit_transform(df[columns])

# %%
df.head(n=10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit(df)
    wcss.append(km.inertia_)

wcss
# Out:
# [22974434.202248596,
#  8596685.707376642,
#  4337876.9295907505,
#  3045046.977966783,
#  2400584.8434677124,
#  2047880.1427659472,
#  1802664.4671219164,
#  1630139.7759137857,
#  1489401.4029270192,
#  1371394.4219433065]

# %%
km1 = KMeans(n_clusters=4)
y_pred = km1.fit_predict(df)
np.unique(y_pred)
# Out:
# array([0, 1, 2, 3])

# %%
from sklearn.ensemble import AdaBoostClassifier
